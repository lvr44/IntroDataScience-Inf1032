# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
file_path = "../Dados/wfp_food_prices_ukr.csv"

food_ukr_data = pd.read_csv(file_path,  dtype='unicode')
food_ukr_data = food_ukr_data[1:]

display(food_ukr_data)
# Out:
#              date       admin1       admin2            market  latitude  \
# 1      2014-03-15          NaN          NaN  National Average       NaN
# 2      2014-03-15          NaN          NaN  National Average       NaN
# 3      2014-03-15          NaN          NaN  National Average       NaN
# 4      2014-03-15          NaN          NaN  National Average       NaN
# 5      2014-03-15          NaN          NaN  National Average       NaN
# ...           ...          ...          ...               ...       ...
# 95496  2023-07-15  Zhytomyrska  Zhytomyrska          Zhytomyr  50.25465
# 95497  2023-07-15  Zhytomyrska  Zhytomyrska          Zhytomyr  50.25465
# 95498  2023-07-15  Zhytomyrska  Zhytomyrska          Zhytomyr  50.25465
# 95499  2023-07-15  Zhytomyrska  Zhytomyrska          Zhytomyr  50.25465
# 95500  2023-07-15  Zhytomyrska  Zhytomyrska          Zhytomyr  50.25465
#
#        longitude               category        commodity  unit priceflag  \
# 1            NaN     cereals and tubers      Bread (rye)  Loaf    actual
# 2            NaN     cereals and tubers    Bread (wheat)  Loaf    actual
# 3            NaN     cereals and tubers  Buckwheat grits    KG    actual
# 4            NaN     cereals and tubers            Pasta    KG    actual
# 5            NaN     cereals and tubers         Potatoes    KG    actual
# ...          ...                    ...              ...   ...       ...
# 95496  28.658667  vegetables and fruits           Apples    KG  forecast
# 95497  28.658667  vegetables and fruits        Beetroots    KG  forecast
# 95498  28.658667  vegetables and fruits          Cabbage    KG  forecast
# 95499  28.658667  vegetables and fruits          Carrots    KG  forecast
# 95500  28.658667  vegetables and fruits           Onions    KG  forecast
#
#       pricetype currency price usdprice
# 1        Retail      UAH  4.96   0.4744
# 2        Retail      UAH  4.84   0.4629
# 3        Retail      UAH  7.44   0.7119
# 4        Retail      UAH  5.34   0.5105
# 5        Retail      UAH  6.74   0.6447
# ...         ...      ...   ...      ...
# 95496    Retail      UAH   0.0      0.0
# 95497    Retail      UAH   0.0      0.0
# 95498    Retail      UAH   0.0      0.0
# 95499    Retail      UAH   0.0      0.0
# 95500    Retail      UAH   0.0      0.0
#
# [95500 rows x 14 columns]

# %%
attrs = ['date', 'market', 'category', 'commodity', 'price', 'usdprice']

aux = food_ukr_data[food_ukr_data['priceflag'] == 'actual']

food_data = aux[attrs].copy()
food_data[['price', 'usdprice']] = food_data.loc[:, ('price', 'usdprice')].apply(pd.to_numeric)


display(food_data)
# Out:
#              date            market               category        commodity  \
# 1      2014-03-15  National Average     cereals and tubers      Bread (rye)
# 2      2014-03-15  National Average     cereals and tubers    Bread (wheat)
# 3      2014-03-15  National Average     cereals and tubers  Buckwheat grits
# 4      2014-03-15  National Average     cereals and tubers            Pasta
# 5      2014-03-15  National Average     cereals and tubers         Potatoes
# ...           ...               ...                    ...              ...
# 77511  2023-01-15          Zhytomyr  vegetables and fruits           Apples
# 77512  2023-01-15          Zhytomyr  vegetables and fruits        Beetroots
# 77513  2023-01-15          Zhytomyr  vegetables and fruits          Cabbage
# 77514  2023-01-15          Zhytomyr  vegetables and fruits          Carrots
# 77515  2023-01-15          Zhytomyr  vegetables and fruits           Onions
#
#        price  usdprice
# 1       4.96    0.4744
# 2       4.84    0.4629
# 3       7.44    0.7119
# 4       5.34    0.5105
# 5       6.74    0.6447
# ...      ...       ...
# 77511  16.23    0.4438
# 77512  11.06    0.3024
# 77513  12.56    0.3435
# 77514  22.19    0.6068
# 77515  30.16    0.8248
#
# [77515 rows x 6 columns]

# %%
def attr_to_list(df: pd.DataFrame, attr: str) -> list:
    try:
        lista = df[attr].unique().tolist()
    except KeyError:
        print(f"'{attr}' não é um atributo do DataFrame")
    finally:
        return lista

# %%
markets = food_data.market.unique().tolist()

print(markets)
# Out:
# ['National Average', 'Crimea', 'Cherkasy', 'Chernihiv', 'Chernivtsi', 'Dnipropetrovsk', 'Donetsk', 'Iv.-Frankivsk', 'Kharkiv', 'Kherson', 'Khmelnytskiy', 'Kirovohrad', 'Kyiv', 'Kyiv city', 'Luhansk', 'Lviv', 'Mykolayiv', 'Odesa', 'Poltava', 'Rivne', 'm. Sevastopol', 'Sumy', 'Ternopyl', 'Vinnytsya', 'Volyn', 'Zakarpattya', 'Zaporizhzhya', 'Zhytomyr']

# %%
# CÉLULA EXCLUSIVAMENTE DE TESTES -> DESCARTAR AO PASSAR PARA RELATÓRIO OFICIAL

capital_data = food_data[food_data["market"] == 'Kyiv']

capital_data = capital_data.sort_values(by='date')

categories = capital_data.category.unique().tolist()

war_start_date = '2022-01-15' # data mais próxima do início da guerra

for category in categories:    
    cat_aux = capital_data[capital_data["category"] == category]
    commodity = attr_to_list(cat_aux, "commodity")#cat_aux.commodity.unique().tolist()

    for label in commodity:
        aux = cat_aux[cat_aux["commodity"] == label]

        date_aux = aux.date.tolist()
        price_aux = aux.price.tolist()

        plt.plot(date_aux, price_aux, label=label)
        
    plt.axvline(x = war_start_date, color = '#0057b7')
    plt.xticks(rotation = 45, ha='right')
    plt.title(f"Price (UAH) of {category} commodities in Ukraine \nfrom {date_aux[0]} to {date_aux[-1]} in Kyiv")
    plt.legend()
    plt.show()

# %%
display(food_data)
# Out:
#              date            market               category        commodity  \
# 1      2014-03-15  National Average     cereals and tubers      Bread (rye)
# 2      2014-03-15  National Average     cereals and tubers    Bread (wheat)
# 3      2014-03-15  National Average     cereals and tubers  Buckwheat grits
# 4      2014-03-15  National Average     cereals and tubers            Pasta
# 5      2014-03-15  National Average     cereals and tubers         Potatoes
# ...           ...               ...                    ...              ...
# 77511  2023-01-15          Zhytomyr  vegetables and fruits           Apples
# 77512  2023-01-15          Zhytomyr  vegetables and fruits        Beetroots
# 77513  2023-01-15          Zhytomyr  vegetables and fruits          Cabbage
# 77514  2023-01-15          Zhytomyr  vegetables and fruits          Carrots
# 77515  2023-01-15          Zhytomyr  vegetables and fruits           Onions
#
#        price  usdprice
# 1       4.96    0.4744
# 2       4.84    0.4629
# 3       7.44    0.7119
# 4       5.34    0.5105
# 5       6.74    0.6447
# ...      ...       ...
# 77511  16.23    0.4438
# 77512  11.06    0.3024
# 77513  12.56    0.3435
# 77514  22.19    0.6068
# 77515  30.16    0.8248
#
# [77515 rows x 6 columns]

# %%
categories = ["cereals and tubers", "vegetables and fruits"]

commodities_data = food_data[food_data['category'].isin(categories)].reset_index()

display(commodities_data)
# Out:
#        index        date            market               category  \
# 0          1  2014-03-15  National Average     cereals and tubers
# 1          2  2014-03-15  National Average     cereals and tubers
# 2          3  2014-03-15  National Average     cereals and tubers
# 3          4  2014-03-15  National Average     cereals and tubers
# 4          5  2014-03-15  National Average     cereals and tubers
# ...      ...         ...               ...                    ...
# 32153  77511  2023-01-15          Zhytomyr  vegetables and fruits
# 32154  77512  2023-01-15          Zhytomyr  vegetables and fruits
# 32155  77513  2023-01-15          Zhytomyr  vegetables and fruits
# 32156  77514  2023-01-15          Zhytomyr  vegetables and fruits
# 32157  77515  2023-01-15          Zhytomyr  vegetables and fruits
#
#              commodity  price  usdprice
# 0          Bread (rye)   4.96    0.4744
# 1        Bread (wheat)   4.84    0.4629
# 2      Buckwheat grits   7.44    0.7119
# 3                Pasta   5.34    0.5105
# 4             Potatoes   6.74    0.6447
# ...                ...    ...       ...
# 32153           Apples  16.23    0.4438
# 32154        Beetroots  11.06    0.3024
# 32155          Cabbage  12.56    0.3435
# 32156          Carrots  22.19    0.6068
# 32157           Onions  30.16    0.8248
#
# [32158 rows x 7 columns]

# %%
capital_data = food_data[food_data["market"] == 'Kyiv']

capital_data = capital_data.sort_values(by='date')

categories = capital_data.category.unique().tolist()

war_start_date = '2022-02-15' # data mais próxima do início da guerra

for category in categories:  
    fig, ax = plt.subplots()
        
    cat_aux = capital_data[capital_data["category"] == category]
    commodity = cat_aux.commodity.unique().tolist()
    dates_list = cat_aux.date.unique().tolist()

    min_date = dates_list[0]
    max_date = dates_list[-1]

    for label in commodity:
        aux = cat_aux[cat_aux["commodity"] == label]

        date_aux = aux.date.tolist()
        price_aux = aux.price.tolist()
            
        plt.plot(date_aux, price_aux, label=label)
    
    start, end = ax.get_xlim()
    steps = 3.5
    
    ax.xaxis.set_ticks(np.arange(start, end, steps))
    
    plt.axvline(x = war_start_date, linestyle = '--', color = '#0057b7')
    plt.xticks(rotation = 45, ha='right')
    plt.title(f"Price (UAH) of {category} commodities in Ukraine \nfrom {min_date} to {max_date} in Kyiv")
    plt.legend(bbox_to_anchor=(1.02, 0.95), loc='upper left', borderaxespad=0)
    plt.show()

# %%
capital_data = food_data[food_data["market"] == 'National Average']

capital_data = capital_data.sort_values(by='date')

categories = capital_data.category.unique().tolist()

war_start_date = '2022-02-15' # data mais próxima do início da guerra

for category in categories:  
    fig, ax = plt.subplots()
        
    cat_aux = capital_data[capital_data["category"] == category]
    commodity = cat_aux.commodity.unique().tolist()
    dates_list = cat_aux.date.unique().tolist()

    min_date = dates_list[0]
    max_date = dates_list[-1]

    for label in commodity:
        aux = cat_aux[cat_aux["commodity"] == label]

        date_aux = aux.date.tolist()
        price_aux = aux.price.tolist()
            
        plt.plot(date_aux, price_aux, label=label)
    
    start, end = ax.get_xlim()
    steps = 3.5
    
    ax.xaxis.set_ticks(np.arange(start, end, steps))
    
    plt.axvline(x = war_start_date, linestyle = '--', color = '#0057b7')
    plt.xticks(rotation = 45, ha='right')
    plt.title(f"Price (UAH) of {category} commodities in Ukraine \nfrom {min_date} to {max_date} in Kyiv")
    plt.legend(bbox_to_anchor=(1.02, 0.95), loc='upper left', borderaxespad=0)
    plt.show()

# %%
allzin = food_data.copy()


for market in marketss:
    print(market, len(allzin[allzin['market'] == market]))
# Out:
# National Average 1125
# Crimea 25
# Cherkasy 3137
# Chernihiv 3019
# Chernivtsi 3137
# Dnipropetrovsk 3137
# Donetsk 2730
# Iv.-Frankivsk 3057
# Kharkiv 2969
# Kherson 3137
# Khmelnytskiy 3124
# Kirovohrad 2987
# Kyiv 3057
# Kyiv city 3022
# Luhansk 2579
# Lviv 3084
# Mykolayiv 3102
# Odesa 3087
# Poltava 3081
# Rivne 3102
# m. Sevastopol 50
# Sumy 3091
# Ternopyl 3037
# Vinnytsya 3137
# Volyn 3137
# Zakarpattya 3091
# Zaporizhzhya 3137
# Zhytomyr 3137

# %%
precos_medios = food_data[food_data['market'] != 'National Average'] 

precos_medios = precos_medios.groupby(['date', 'category', 'commodity']).mean('price').reset_index()

display(precos_medios)
# Out:
#             date               category        commodity      price  usdprice
# 0     2014-03-15     cereals and tubers      Bread (rye)   4.907407  0.469341
# 1     2014-03-15     cereals and tubers    Bread (wheat)   4.840385  0.463004
# 2     2014-03-15     cereals and tubers  Buckwheat grits   7.429259  0.710659
# 3     2014-03-15     cereals and tubers            Pasta   5.385926  0.515170
# 4     2014-03-15     cereals and tubers         Potatoes   6.637037  0.634807
# ...          ...                    ...              ...        ...       ...
# 3132  2023-01-15  vegetables and fruits           Apples  15.615000  0.426994
# 3133  2023-01-15  vegetables and fruits        Beetroots  12.033333  0.329056
# 3134  2023-01-15  vegetables and fruits          Cabbage  12.829444  0.350828
# 3135  2023-01-15  vegetables and fruits          Carrots  24.417778  0.667733
# 3136  2023-01-15  vegetables and fruits           Onions  32.007778  0.875289
#
# [3137 rows x 5 columns]

# %%
nat_avg = precos_medios.copy()#[precos_medios["market"] == 'National Average']

nat_avg = nat_avg.sort_values(by='date')

categories = nat_avg.category.unique().tolist()

war_start_date = '2022-02-15' # data mais próxima do início da guerra

for category in categories:  
    fig, ax = plt.subplots()
        
    cat_aux = nat_avg[nat_avg["category"] == category]
    commodity = cat_aux.commodity.unique().tolist()
    dates_list = cat_aux.date.unique().tolist()

    min_date = dates_list[0]
    max_date = dates_list[-1]

    for label in commodity:
        aux = cat_aux[cat_aux["commodity"] == label]

        date_aux = aux.date.tolist()
        price_aux = aux.price.tolist()
            
        plt.plot(date_aux, price_aux, label=label)
    
    start, end = ax.get_xlim()
    steps = 3.5
    
    ax.xaxis.set_ticks(np.arange(start, end, steps))
    
    plt.axvline(x = war_start_date, linestyle = '--', color = '#0057b7')
    plt.xticks(rotation = 45, ha='right')
    plt.title(f"Average price (UAH) of {category} commodities\n in Ukraine from {min_date} to {max_date}")
    plt.legend(bbox_to_anchor=(1.02, 0.95), loc='upper left', borderaxespad=0)
    plt.show()

# %%
food_data['oi']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'oi'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 food_data['oi']
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'oi'
